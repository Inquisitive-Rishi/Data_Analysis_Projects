# %% [markdown]
# # Pandas Group By:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Pokemon.csv")
df
# Out:
#      Num        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# 0         65     45      1      False
# 1         80     60      2      False
# 2        100     80      3      False
# 3         50     65      1      False
# 4         65     80      2      False
# ..       ...    ...    ...        ...
# 146       50     50      1      False
# 147       70     70      2      False
# 148      100     80      3      False
# 149       90    130      1       True
# 150      100    100      1      False
#
# [151 rows x 13 columns]

# %%
df = df[['Name','Type 1','Type 2','Total','HP','Attack']]

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack
# 0   Bulbasaur  Grass  Poison    318  45      49
# 1     Ivysaur  Grass  Poison    405  60      62
# 2    Venusaur  Grass  Poison    525  80      82
# 3  Charmander   Fire     NaN    309  39      52
# 4  Charmeleon   Fire     NaN    405  58      64

# %%
gpp = df.groupby("Type 1")

# %% [markdown]
# ## Viewing Each Group & 'Indexes' Individually

# %%
gpp.groups
# Out:
# {'Bug': [9, 10, 11, 12, 13, 14, 45, 46, 47, 48, 122, 126], 'Dragon': [146, 147, 148], 'Electric': [24, 25, 80, 81, 99, 100, 124, 134, 144], 'Fairy': [34, 35], 'Fighting': [55, 56, 65, 66, 67, 105, 106], 'Fire': [3, 4, 5, 36, 37, 57, 58, 76, 77, 125, 135, 145], 'Ghost': [91, 92, 93], 'Grass': [0, 1, 2, 42, 43, 44, 68, 69, 70, 101, 102, 113], 'Ground': [26, 27, 49, 50, 103, 104, 110, 111], 'Ice': [123, 143], 'Normal': [15, 16, 17, 18, 19, 20, 21, 38, 39, 51, 52, 82, 83, 84, 107, 112, 114, 127, 131, 132, 136, 142], 'Poison': [22, 23, 28, 29, 30, 31, 32, 33, 40, 41, 87, 88, 108, 109], 'Psychic': [62, 63, 64, 95, 96, 121, 149, 150], 'Rock': [73, 74, 75, 94, 137, 138, 139, 140, 141], 'Water': [6, 7, 8, 53, 54, 59, 60, 61, 71, 72, 78, 79, 85, 86, 89, 90, 97, 98, 115, 116, 117, 118, 119, 120, 128, 129, 130, 133]}

# %%
gpp.ngroups
# Out:
# 15

# %%
gpp.get_group("Grass")
# Out:
#            Name Type 1   Type 2  Total  HP  Attack
# 0     Bulbasaur  Grass   Poison    318  45      49
# 1       Ivysaur  Grass   Poison    405  60      62
# 2      Venusaur  Grass   Poison    525  80      82
# 42       Oddish  Grass   Poison    320  45      50
# 43        Gloom  Grass   Poison    395  60      65
# 44    Vileplume  Grass   Poison    490  75      80
# 68   Bellsprout  Grass   Poison    300  50      75
# 69   Weepinbell  Grass   Poison    390  65      90
# 70   Victreebel  Grass   Poison    490  80     105
# 101   Exeggcute  Grass  Psychic    325  60      40
# 102   Exeggutor  Grass  Psychic    520  95      95
# 113     Tangela  Grass      NaN    435  65      55

# %% [markdown]
# ## Applying loops to view Each Group and their values

# %%
for name,group in gpp:
    print(name)
    print("="*20)
    print(group)
    print()
# Out:
# Bug
# ====================
#            Name Type 1  Type 2  Total  HP  Attack
# 9      Caterpie    Bug     NaN    195  45      30
# 10      Metapod    Bug     NaN    205  50      20
# 11   Butterfree    Bug  Flying    395  60      45
# 12       Weedle    Bug  Poison    195  40      35
# 13       Kakuna    Bug  Poison    205  45      25
# 14     Beedrill    Bug  Poison    395  65      90
# 45        Paras    Bug   Grass    285  35      70
# 46     Parasect    Bug   Grass    405  60      95
# 47      Venonat    Bug  Poison    305  60      55
# 48     Venomoth    Bug  Poison    450  70      65
# 122     Scyther    Bug  Flying    500  70     110
# 126      Pinsir    Bug     NaN    500  65     125
#
# Dragon
# ====================
#           Name  Type 1  Type 2  Total  HP  Attack
# 146    Dratini  Dragon     NaN    300  41      64
# 147  Dragonair  Dragon     NaN    420  61      84
# 148  Dragonite  Dragon  Flying    600  91     134
#
# Electric
# ====================
#            Name    Type 1  Type 2  Total  HP  Attack
# 24      Pikachu  Electric     NaN    320  35      55
# 25       Raichu  Electric     NaN    485  60      90
# 80    Magnemite  Electric   Steel    325  25      35
# 81     Magneton  Electric   Steel    465  50      60
# 99      Voltorb  Electric     NaN    330  40      30
# 100   Electrode  Electric     NaN    480  60      50
# 124  Electabuzz  Electric     NaN    490  65      83
# 134     Jolteon  Electric     NaN    525  65      65
# 144      Zapdos  Electric  Flying    580  90      90
#
# Fairy
# ====================
#         Name Type 1 Type 2  Total  HP  Attack
# 34  Clefairy  Fairy    NaN    323  70      45
# 35  Clefable  Fairy    NaN    483  95      70
#
# Fighting
# ====================
#            Name    Type 1 Type 2  Total  HP  Attack
# 55       Mankey  Fighting    NaN    305  40      80
# 56     Primeape  Fighting    NaN    455  65     105
# 65       Machop  Fighting    NaN    305  70      80
# 66      Machoke  Fighting    NaN    405  80     100
# 67      Machamp  Fighting    NaN    505  90     130
# 105   Hitmonlee  Fighting    NaN    455  50     120
# 106  Hitmonchan  Fighting    NaN    455  50     105
#
# Fire
# ====================
#            Name Type 1  Type 2  Total  HP  Attack
# 3    Charmander   Fire     NaN    309  39      52
# 4    Charmeleon   Fire     NaN    405  58      64
# 5     Charizard   Fire  Flying    534  78      84
# 36       Vulpix   Fire     NaN    299  38      41
# 37    Ninetales   Fire     NaN    505  73      76
# 57    Growlithe   Fire     NaN    350  55      70
# 58     Arcanine   Fire     NaN    555  90     110
# 76       Ponyta   Fire     NaN    410  50      85
# 77     Rapidash   Fire     NaN    500  65     100
# 125      Magmar   Fire     NaN    495  65      95
# 135     Flareon   Fire     NaN    525  65     130
# 145     Moltres   Fire  Flying    580  90     100
#
# Ghost
# ====================
#        Name Type 1  Type 2  Total  HP  Attack
# 91   Gastly  Ghost  Poison    310  30      35
# 92  Haunter  Ghost  Poison    405  45      50
# 93   Gengar  Ghost  Poison    500  60      65
#
# Grass
# ====================
#            Name Type 1   Type 2  Total  HP  Attack
# 0     Bulbasaur  Grass   Poison    318  45      49
# 1       Ivysaur  Grass   Poison    405  60      62
# 2      Venusaur  Grass   Poison    525  80      82
# 42       Oddish  Grass   Poison    320  45      50
# 43        Gloom  Grass   Poison    395  60      65
# 44    Vileplume  Grass   Poison    490  75      80
# 68   Bellsprout  Grass   Poison    300  50      75
# 69   Weepinbell  Grass   Poison    390  65      90
# 70   Victreebel  Grass   Poison    490  80     105
# 101   Exeggcute  Grass  Psychic    325  60      40
# 102   Exeggutor  Grass  Psychic    520  95      95
# 113     Tangela  Grass      NaN    435  65      55
#
# Ground
# ====================
#           Name  Type 1 Type 2  Total   HP  Attack
# 26   Sandshrew  Ground    NaN    300   50      75
# 27   Sandslash  Ground    NaN    450   75     100
# 49     Diglett  Ground    NaN    265   10      55
# 50     Dugtrio  Ground    NaN    405   35      80
# 103     Cubone  Ground    NaN    320   50      50
# 104    Marowak  Ground    NaN    425   60      80
# 110    Rhyhorn  Ground   Rock    345   80      85
# 111     Rhydon  Ground   Rock    485  105     130
#
# Ice
# ====================
#          Name Type 1   Type 2  Total  HP  Attack
# 123      Jynx    Ice  Psychic    455  65      50
# 143  Articuno    Ice   Flying    580  90      85
#
# Normal
# ====================
#            Name  Type 1  Type 2  Total   HP  Attack
# 15       Pidgey  Normal  Flying    251   40      45
# 16    Pidgeotto  Normal  Flying    349   63      60
# 17      Pidgeot  Normal  Flying    479   83      80
# 18      Rattata  Normal     NaN    253   30      56
# 19     Raticate  Normal     NaN    413   55      81
# 20      Spearow  Normal  Flying    262   40      60
# 21       Fearow  Normal  Flying    442   65      90
# 38   Jigglypuff  Normal   Fairy    270  115      45
# 39   Wigglytuff  Normal   Fairy    435  140      70
# 51       Meowth  Normal     NaN    290   40      45
# 52      Persian  Normal     NaN    440   65      70
# 82   Farfetch'd  Normal  Flying    352   52      65
# 83        Doduo  Normal  Flying    310   35      85
# 84       Dodrio  Normal  Flying    460   60     110
# 107   Lickitung  Normal     NaN    385   90      55
# 112     Chansey  Normal     NaN    450  250       5
# 114  Kangaskhan  Normal     NaN    490  105      95
# 127      Tauros  Normal     NaN    490   75     100
# 131       Ditto  Normal     NaN    288   48      48
# 132       Eevee  Normal     NaN    325   55      55
# 136     Porygon  Normal     NaN    395   65      60
# 142     Snorlax  Normal     NaN    540  160     110
#
# Poison
# ====================
#            Name  Type 1  Type 2  Total   HP  Attack
# 22        Ekans  Poison     NaN    288   35      60
# 23        Arbok  Poison     NaN    438   60      85
# 28   Nidoran���  Poison     NaN    275   55      47
# 29     Nidorina  Poison     NaN    365   70      62
# 30    Nidoqueen  Poison  Ground    505   90      92
# 31   Nidoran���  Poison     NaN    273   46      57
# 32     Nidorino  Poison     NaN    365   61      72
# 33     Nidoking  Poison  Ground    505   81     102
# 40        Zubat  Poison  Flying    245   40      45
# 41       Golbat  Poison  Flying    455   75      80
# 87       Grimer  Poison     NaN    325   80      80
# 88          Muk  Poison     NaN    500  105     105
# 108     Koffing  Poison     NaN    340   40      65
# 109     Weezing  Poison     NaN    490   65      90
#
# Psychic
# ====================
#          Name   Type 1 Type 2  Total   HP  Attack
# 62       Abra  Psychic    NaN    310   25      20
# 63    Kadabra  Psychic    NaN    400   40      35
# 64   Alakazam  Psychic    NaN    500   55      50
# 95    Drowzee  Psychic    NaN    328   60      48
# 96      Hypno  Psychic    NaN    483   85      73
# 121  Mr. Mime  Psychic  Fairy    460   40      45
# 149    Mewtwo  Psychic    NaN    680  106     110
# 150       Mew  Psychic    NaN    600  100     100
#
# Rock
# ====================
#            Name Type 1  Type 2  Total  HP  Attack
# 73      Geodude   Rock  Ground    300  40      80
# 74     Graveler   Rock  Ground    390  55      95
# 75        Golem   Rock  Ground    495  80     120
# 94         Onix   Rock  Ground    385  35      45
# 137     Omanyte   Rock   Water    355  35      40
# 138     Omastar   Rock   Water    495  70      60
# 139      Kabuto   Rock   Water    355  30      80
# 140    Kabutops   Rock   Water    495  60     115
# 141  Aerodactyl   Rock  Flying    515  80     105
#
# Water
# ====================
#            Name Type 1    Type 2  Total   HP  Attack
# 6      Squirtle  Water       NaN    314   44      48
# 7     Wartortle  Water       NaN    405   59      63
# 8     Blastoise  Water       NaN    530   79      83
# 53      Psyduck  Water       NaN    320   50      52
# 54      Golduck  Water       NaN    500   80      82
# 59      Poliwag  Water       NaN    300   40      50
# 60    Poliwhirl  Water       NaN    385   65      65
# 61    Poliwrath  Water  Fighting    510   90      95
# 71    Tentacool  Water    Poison    335   40      40
# 72   Tentacruel  Water    Poison    515   80      70
# 78     Slowpoke  Water   Psychic    315   90      65
# 79      Slowbro  Water   Psychic    490   95      75
# 85         Seel  Water       NaN    325   65      45
# 86      Dewgong  Water       Ice    475   90      70
# 89     Shellder  Water       NaN    305   30      65
# 90     Cloyster  Water       Ice    525   50      95
# 97       Krabby  Water       NaN    325   30     105
# 98      Kingler  Water       NaN    475   55     130
# 115      Horsea  Water       NaN    295   30      40
# 116      Seadra  Water       NaN    440   55      65
# 117     Goldeen  Water       NaN    320   45      67
# 118     Seaking  Water       NaN    450   80      92
# 119      Staryu  Water       NaN    340   30      45
# 120     Starmie  Water   Psychic    520   60      75
# 128    Magikarp  Water       NaN    200   20      10
# 129    Gyarados  Water    Flying    540   95     125
# 130      Lapras  Water       Ice    535  130      85
# 133    Vaporeon  Water       NaN    525  130      65

# %%
gpp["HP"].mean()
# Out:
# Type 1
# Bug         55.416667
# Dragon      64.333333
# Electric    54.444444
# Fairy       82.500000
# Fighting    63.571429
# Fire        63.833333
# Ghost       45.000000
# Grass       65.000000
# Ground      58.125000
# Ice         77.500000
# Normal      78.681818
# Poison      64.500000
# Psychic     63.875000
# Rock        53.888889
# Water       64.535714
# Name: HP, dtype: float64

# %% [markdown]
# ## Plotting by Group

# %%
gpp["HP"].mean().plot(kind="barh",xlabel="HP")
# Out:
# <Axes: xlabel='HP', ylabel='Type 1'>

# %% [markdown]
# ### Using Aggregate to perform functions on multiple columns

# %%
df.groupby("Type 1").agg({"HP":["min","max"], "Attack":["min","max"],"Total":"mean"})
# Out:
#           HP      Attack            Total
#          min  max    min  max        mean
# Type 1
# Bug       35   70     20  125  336.250000
# Dragon    41   91     64  134  440.000000
# Electric  25   90     30   90  444.444444
# Fairy     70   95     45   70  403.000000
# Fighting  40   90     80  130  412.142857
# Fire      38   90     41  130  455.583333
# Ghost     30   60     35   65  405.000000
# Grass     45   95     40  105  409.416667
# Ground    10  105     50  130  374.375000
# Ice       65   90     50   85  517.500000
# Normal    30  250      5  110  380.409091
# Poison    35  105     45  105  383.500000
# Psychic   25  106     20  110  470.125000
# Rock      30   80     40  120  420.555556
# Water     20  130     10  130  411.214286

# %%
df.groupby("Type 1")["HP"].agg({"max","min"})
# Out:
#           max  min
# Type 1
# Bug        70   35
# Dragon     91   41
# Electric   90   25
# Fairy      95   70
# Fighting   90   40
# Fire       90   38
# Ghost      60   30
# Grass      95   45
# Ground    105   10
# Ice        90   65
# Normal    250   30
# Poison    105   35
# Psychic   106   25
# Rock       80   30
# Water     130   20

# %%
def range(x):
    return x.max() - x.min()

# %%
df.groupby("Type 1")["HP"].agg(["max","min",range])
# Out:
#           max  min  range
# Type 1
# Bug        70   35     35
# Dragon     91   41     50
# Electric   90   25     65
# Fairy      95   70     25
# Fighting   90   40     50
# Fire       90   38     52
# Ghost      60   30     30
# Grass      95   45     50
# Ground    105   10     95
# Ice        90   65     25
# Normal    250   30    220
# Poison    105   35     70
# Psychic   106   25     81
# Rock       80   30     50
# Water     130   20    110

# %% [markdown]
# ## Total no of null Values:

# %%
df["Type 2"].size - df["Type 1"].count()
# Out:
# 0

# %% [markdown]
# ### defining custom function to calulate null values

# %%
def null_count(s):
    return s.size-s.count()

# %%
df.groupby("Type 1")["Type 2"].agg(null_count)
# Out:
# Type 1
# Bug          3
# Dragon       2
# Electric     6
# Fairy        2
# Fighting     7
# Fire        10
# Ghost        0
# Grass        1
# Ground       6
# Ice          0
# Normal      12
# Poison      10
# Psychic      7
# Rock         0
# Water       18
# Name: Type 2, dtype: int64

# %% [markdown]
# ## Named Aggregation:
#
#             > We can provide custom names to our aggregate functions.
#             such as max --> custom_max   min --> custom_min

# %%
df = pd.read_csv("Pokemon.csv")
df = df[["Name","Type 1","Type 2","Total","HP","Attack","Defense","Speed"]]

# %%
df
# Out:
#            Name   Type 1  Type 2  Total   HP  Attack  Defense  Speed
# 0     Bulbasaur    Grass  Poison    318   45      49       49     45
# 1       Ivysaur    Grass  Poison    405   60      62       63     60
# 2      Venusaur    Grass  Poison    525   80      82       83     80
# 3    Charmander     Fire     NaN    309   39      52       43     65
# 4    Charmeleon     Fire     NaN    405   58      64       58     80
# ..          ...      ...     ...    ...  ...     ...      ...    ...
# 146     Dratini   Dragon     NaN    300   41      64       45     50
# 147   Dragonair   Dragon     NaN    420   61      84       65     70
# 148   Dragonite   Dragon  Flying    600   91     134       95     80
# 149      Mewtwo  Psychic     NaN    680  106     110       90    130
# 150         Mew  Psychic     NaN    600  100     100      100    100
#
# [151 rows x 8 columns]

# %%
df.groupby("Type 1").agg(
    max_speed=("Speed","max"),
    min_speed=("Speed","min"),
    avg_HP=("HP","mean"),
    max_HP=("HP","max"),
    min_HP=("HP","min")
)
# Out:
#           max_speed  min_speed     avg_HP  max_HP  min_HP
# Type 1
# Bug             105         25  55.416667      70      35
# Dragon           80         50  64.333333      91      41
# Electric        140         45  54.444444      90      25
# Fairy            60         35  82.500000      95      70
# Fighting         95         35  63.571429      90      40
# Fire            105         60  63.833333      90      38
# Ghost           110         80  45.000000      60      30
# Grass            80         30  65.000000      95      45
# Ground          120         25  58.125000     105      10
# Ice              95         85  77.500000      90      65
# Normal          115         20  78.681818     250      30
# Poison           90         25  64.500000     105      35
# Psychic         130         42  63.875000     106      25
# Rock            130         20  53.888889      80      30
# Water           115         15  64.535714     130      20
