# %% [markdown]
# # Working with Texts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
med = pd.read_csv("mount_everest_deaths.csv")
med
# Out:
#      No.                    Name          Date   Age  \
# 0      1                   Dorje  June 7, 1922   NaN
# 1      2                  Lhakpa  June 7, 1922   NaN
# 2      3                   Norbu  June 7, 1922   NaN
# 3      4                  Pasang  June 7, 1922   NaN
# 4      5                    Pema  June 7, 1922   NaN
# ..   ...                     ...           ...   ...
# 305  306  Christopher Jon Kulish  May 27, 2019  62.0
# 306  307               Puwei Liu  May 12, 2021  55.0
# 307  308           Abdul Waraich  May 12, 2021  41.0
# 308  309      Pemba Tashi Sherpa  May 18, 2021  28.0
# 309  310      Wong Dorchi Sherpa  May 23, 2021   NaN
#
#                                 Expedition    Nationality  \
# 0    1922 British Mount Everest Expedition          Nepal
# 1    1922 British Mount Everest Expedition          Nepal
# 2    1922 British Mount Everest Expedition          Nepal
# 3    1922 British Mount Everest Expedition          Nepal
# ...

# %%
med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No.             310 non-null    int64
#  1   Name            310 non-null    object
#  2   Date            310 non-null    object
#  3   Age             160 non-null    float64
#  4   Expedition      271 non-null    object
#  5   Nationality     309 non-null    object
#  6   Cause of death  296 non-null    object
#  7   Location        291 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 19.5+ KB

# %% [markdown]
# Here fields with Object Data Type can be anything
# i.e strings/boolean/numbers/arrays
#
# i.e we can change them into any one of them

# %%
med["Name"][0]
# Out:
# 'Dorje'

# %%
med["Name"][0] = [1,2,3]
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16964\3468386441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   med["Name"][0] = [1,2,3]

# %%
med.head(3)
# Out:
#    No.       Name          Date  Age                             Expedition  \
# 0    1  [1, 2, 3]  June 7, 1922  NaN  1922 British Mount Everest Expedition
# 1    2     Lhakpa  June 7, 1922  NaN  1922 British Mount Everest Expedition
# 2    3      Norbu  June 7, 1922  NaN  1922 British Mount Everest Expedition
#
#   Nationality Cause of death         Location
# 0       Nepal      Avalanche  Below North Col
# 1       Nepal      Avalanche  Below North Col
# 2       Nepal      Avalanche  Below North Col

# %%
med["Name"].astype("string")[0]
# Out:
# '[1, 2, 3]'

# %%
# To reset the changes, we need to import the data.
med = pd.read_csv("mount_everest_deaths.csv")
med.head()
# Out:
#    No.    Name          Date  Age                             Expedition  \
# 0    1   Dorje  June 7, 1922  NaN  1922 British Mount Everest Expedition
# 1    2  Lhakpa  June 7, 1922  NaN  1922 British Mount Everest Expedition
# 2    3   Norbu  June 7, 1922  NaN  1922 British Mount Everest Expedition
# 3    4  Pasang  June 7, 1922  NaN  1922 British Mount Everest Expedition
# 4    5    Pema  June 7, 1922  NaN  1922 British Mount Everest Expedition
#
#   Nationality Cause of death         Location
# 0       Nepal      Avalanche  Below North Col
# 1       Nepal      Avalanche  Below North Col
# 2       Nepal      Avalanche  Below North Col
# 3       Nepal      Avalanche  Below North Col
# 4       Nepal      Avalanche  Below North Col

# %% [markdown]
# ## upper()  lower()  capitalize()

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
"MEssAGe".lower()
# Out:
# 'message'

# %%
"MeSSage".lower()
# Out:
# 'message'

# %%
'message'.capitalize()
# Out:
# 'Message'

# %%
med["Expedition"].str.upper()
# Out:
# 0      1922 BRITISH MOUNT EVEREST EXPEDITION
# 1      1922 BRITISH MOUNT EVEREST EXPEDITION
# 2      1922 BRITISH MOUNT EVEREST EXPEDITION
# 3      1922 BRITISH MOUNT EVEREST EXPEDITION
# 4      1922 BRITISH MOUNT EVEREST EXPEDITION
#                        ...
# 305               CLIMBING THE SEVEN SUMMITS
# 306                       SEVEN SUMMIT TREKS
# 307                       SEVEN SUMMIT TREKS
# 308               CLIMBING THE SEVEN SUMMITS
# 309                           7 SUMMITS CLUB
# Name: Expedition, Length: 310, dtype: object

# %% [markdown]
# ## Indexing String series with [  ]

# %%
"Namaste"[0]
# Out:
# 'N'

# %%
"Namaste"[3:7]
# Out:
# 'aste'

# %%
med["Nationality"][0:30:5]
# Out:
# 0              Nepal
# 5              Nepal
# 10    United Kingdom
# 15             Nepal
# 20             Nepal
# 25             Japan
# Name: Nationality, dtype: object

# %%
med["Nationality"][0][2]
# Out:
# 'p'

# %%
# Now we create a new column 'country-code' that contains 
# first two character of 'Nationality' column 
med["country_code"] = med["Nationality"].str[0:2]
med["country_code"].head()
# Out:
# 0    Ne
# 1    Ne
# 2    Ne
# 3    Ne
# 4    Ne
# Name: country_code, dtype: object

# %%
med["country_code"] = med["country_code"].str.upper()
med["country_code"]
# Out:
# 0      NE
# 1      NE
# 2      NE
# 3      NE
# 4      NE
#        ..
# 305    UN
# 306    UN
# 307    SW
# 308    NE
# 309    NE
# Name: country_code, Length: 310, dtype: object

# %%
# Plotting avg age from every country
med.groupby("Nationality")["Age"].mean().sort_values().plot(kind="bar")
plt.ylabel("Avg_Age")
# Out:
# Text(0, 0.5, 'Avg_Age')

# %% [markdown]
# ## Stripping whitespace using .strip()

# %%
s = pd.Series(["1.   Arjun  ","  2. Drona\n  ","  3.  Bhishma "])
s
# Out:
# 0      1.   Arjun
# 1      2. Drona\n
# 2      3.  Bhishma
# dtype: object

# %%
s.str.strip()
# Out:
# 0     1.   Arjun
# 1       2. Drona
# 2    3.  Bhishma
# dtype: object

# %%
# We can also choose what to strip
s.str.strip(to_strip="123. \n")
# Out:
# 0      Arjun
# 1      Drona
# 2    Bhishma
# dtype: object

# %%
# Removes whitespace from the left
s.str.lstrip()
# Out:
# 0    1.   Arjun
# 1    2. Drona\n
# 2    3.  Bhishma
# dtype: object

# %%
# Remove whitespace from the right
s.str.rstrip()
# Out:
# 0       1.   Arjun
# 1         2. Drona
# 2      3.  Bhishma
# dtype: object

# %% [markdown]
# ## Splitting Text values with .split()

# %%
titanic = pd.read_csv("titanic.csv")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic["home.dest"]
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                                  ?
# 1305                                  ?
# 1306                                  ?
# 1307                                  ?
# 1308                                  ?
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic["home.dest"].str.split()
# Out:
# 0                            [St, Louis,, MO]
# 1       [Montreal,, PQ, /, Chesterville,, ON]
# 2       [Montreal,, PQ, /, Chesterville,, ON]
# 3       [Montreal,, PQ, /, Chesterville,, ON]
# 4       [Montreal,, PQ, /, Chesterville,, ON]
#                         ...
# 1304                                      [?]
# 1305                                      [?]
# 1306                                      [?]
# 1307                                      [?]
# 1308                                      [?]
# Name: home.dest, Length: 1309, dtype: object

# %%
# We can split these into separate rows i.e home, destination
# Here we will defina a separator.
# .split() by default separates on the basis of 'space'
titanic["home.dest"].str.split("/")
# Out:
# 0                           [St Louis, MO]
# 1       [Montreal, PQ ,  Chesterville, ON]
# 2       [Montreal, PQ ,  Chesterville, ON]
# 3       [Montreal, PQ ,  Chesterville, ON]
# 4       [Montreal, PQ ,  Chesterville, ON]
#                        ...
# 1304                                   [?]
# 1305                                   [?]
# 1306                                   [?]
# 1307                                   [?]
# 1308                                   [?]
# Name: home.dest, Length: 1309, dtype: object

# %%
# Now we will define separate columns for home and destination
titanic["home.dest"].str.split("/",expand=True)[0]
# Out:
# 0        St Louis, MO
# 1       Montreal, PQ
# 2       Montreal, PQ
# 3       Montreal, PQ
# 4       Montreal, PQ
#             ...
# 1304                ?
# 1305                ?
# 1306                ?
# 1307                ?
# 1308                ?
# Name: 0, Length: 1309, dtype: object

# %%
titanic["home"] = titanic["home.dest"].str.split("/",expand=True)[0]
titanic["destination"] = titanic["home.dest"].str.split("/",expand=True)[1]

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest        destination           home
# ...

# %%
# Here expand prints a dataframe
# We can define how many times to split by using n 
titanic["home.dest"].str.split("/",expand=True,n=1)
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %% [markdown]
# ## Replacing portion of string with replace()

# %%
# .replace() replaces string from all rows of a column.

# %%
titanic["cabin"].str.replace("?","???")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16964\2448238488.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   titanic["cabin"].str.replace("?","???")
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        ???
# 1305        ???
# 1306        ???
# 1307        ???
# 1308        ???
# Name: cabin, Length: 1309, dtype: object

# %%
ufo = pd.read_csv("nuforc_reports.csv")
ufo["duration"].str.replace("seconds","sec")
# Out:
# 0            5 sec
# 1          3-5 sec
# 2              NaN
# 3           10 sec
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121       20 sec
# 88122       20 sec
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
# To replace two or more strings, we use OR(\) regex
ufo["duration"].str.replace("seconds|minutes","",regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
# Dynamically apply strings by using custom function
def abbrev(reo):
    print(reo)
    return"HI"
# If we include this in the code, it prints all the rows with 'reo' 
# reo:'Regular Expression Object'

# %%
ufo["duration"].str.replace("seconds|minutes",abbrev)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16964\4017768276.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ufo["duration"].str.replace("seconds|minutes",abbrev)
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# ...

# %%
# We can make custom function to extract only first string charater from string.
def abbrev(reo):
    return reo.group()[0]
# This prints only first character from string

# %%
ufo['duration'].str.replace("seconds|minutes",abbrev)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16964\3975124759.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ufo['duration'].str.replace("seconds|minutes",abbrev)
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %% [markdown]
# ## Testing strings with .contains()

# %%
# .contains() checks if the columns contain a string in rows and returns boolean.
ufo["duration"].head()
# Out:
# 0      5 seconds
# 1    3-5 seconds
# 2            NaN
# 3     10 seconds
# 4      2 minutes
# Name: duration, dtype: object

# %%
ufo["duration"].str.contains("s").head(10)
# Out:
# 0     True
# 1     True
# 2      NaN
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9    False
# Name: duration, dtype: object

# %%
# It shows error if NaN is present
ufo[ufo["duration"].str.contains("s")]
# To avoid this error we use na=False
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 2
#       1 # It shows error if NaN is present
# ----> 2 ufo[ufo["duration"].str.contains("s")]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3797, in DataFrame.__getitem__(self, key)
#    3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
# -> 3797 if com.is_bool_indexer(key):
#    3798     return self._getitem_bool_array(key)
#    3800 # We are left with two options: a single key, and a collection of keys,
#    3801 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\anaconda3\lib\site-packages\pandas\core\common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
# ...

# %%
ufo[ufo["duration"].str.contains("s",na=False)].head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
# 5  The object has flashing lights that are green,...  Kirbyville    TX
#
#              date_time     shape     duration  \
# 0  2019-12-12T18:43:00     light    5 seconds
# 1  2019-03-22T18:30:00    circle  3-5 seconds
# 3  2019-04-17T02:00:00  teardrop   10 seconds
# 4  2009-03-15T18:00:00     cigar    2 minutes
# 5  2019-04-02T20:25:00      disk   15 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 3  Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# ...

# %%
ufo[ufo["duration"].str.contains("day|week|month",na=False)].head()
# Out:
#                                                 summary  \
# 107   7 large yellow lights with red center  estimat...
# 116   Saw one large ship during the day around noon ...
# 286   film makers in hollywood where talking of film...
# 290                              End of the Century UFO
# 1355  A white ball of light made several appearances...
#
#                          city state            date_time      shape  \
# 107                   Griffin    GA  1984-03-15T20:00:00     circle
# 116                 Knoxville    TN  1986-04-04T23:00:00  rectangle
# 286                   Arizona    AZ  1997-07-07T00:00:00   triangle
# 290   Cebu City (Philippines)   NaN  1998-03-01T20:00:00      other
# 1355                    Genoa    IL  2007-01-25T22:00:00     sphere
#
#            duration                                              stats  \
# 107        3 months  Occurred : 3/15/1984 20:00  (Entered as : marc...
# 116            week  Occurred : 4/4/1986 23:00  (Entered as : 03150...
# ...
