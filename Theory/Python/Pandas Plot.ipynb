# %% [markdown]
# # Pandas Plotting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv("titanic.csv")
titanic["sex"].value_counts().plot(kind="barh")
# Out:
# <Axes: >

# %%
pokemon = pd.read_csv("Pokemon.csv")
pokemon[["HP","Speed"]].head(10).plot(kind="bar")
# Indexes of the Dataframe goes to x-axis
# Out:
# <Axes: >

# %% [raw]
# > Sometimes, we need to coerce errors from series to plot a graph

# %% [raw]
# Changing Pandas plot styles:
#     Same as in Matplotlib.
#         > plt.style.available
#         > plt.style.use("---")

# %% [markdown]
# ## Adding lables and titles in Pandas Plot

# %% [raw]
# We can add labels and title directly to pandas plot() method.
# But, using Matplotlib along with pandas is much more flexible

# %%
ufo = pd.read_csv("nuforc_reports.csv",parse_dates=["date_time"])
ufo["date_time"].dt.month.value_counts().sort_index().plot(kind="bar")
plt.title("UFO sighthings by Month")
plt.xlabel("Month",fontsize=15,color="brown")
plt.ylabel("Name of Sightings",fontsize=15,color="red")
# Out:
# Text(0, 0.5, 'Name of Sightings')

# %% [raw]
# Using 'rename' when plotting
#     > Renaming x axis name using .rename({1:x})

# %%
sightings = ufo["date_time"].dt.month.value_counts().sort_index()
sightings
# renaming 1 to Jan....12 to Dec
# Out:
# 1.0      5979
# 2.0      4559
# 3.0      5494
# 4.0      5817
# 5.0      6063
# 6.0      8357
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 11.0     7596
# 12.0     6525
# Name: date_time, dtype: int64

# %%
sightings.rename({1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"June",7:"July",
                 8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"})
# Out:
# Jan      5979
# Feb      4559
# Mar      5494
# Apr      5817
# May      6063
# June     8357
# July    10682
# Aug      8997
# Sep      8498
# Oct      8371
# Nov      7596
# Dec      6525
# Name: date_time, dtype: int64

# %%
named_index = {1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"June",7:"July",
                 8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"}

# %%
sightings.rename(named_index)
# After this we could apply renames styles to plot
# Out:
# Jan      5979
# Feb      4559
# Mar      5494
# Apr      5817
# May      6063
# June     8357
# July    10682
# Aug      8997
# Sep      8498
# Oct      8371
# Nov      7596
# Dec      6525
# Name: date_time, dtype: int64

# %% [markdown]
# ## Pandas Bar Plot in depth

# %% [raw]
# When we plot more than one column then, we can 'stack' each bar on top of each
# other using stacked=True

# %%
pokemon[["Speed","Attack","Defense"]].head().plot.bar(stacked=True)
# We can use plot.bar or .plot(kind="bar")
# Out:
# <Axes: >

# %%
pokemon[["Speed","Attack","Defense"]].head().plot.barh(stacked=True)
# plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# ## Pandas Histogram

# %% [raw]
# Three ways to plot a Histogram:
#         1. df.plot(kind="hist")
#         2. df.plot.hist()
#         3. df.hist()
#
# df.hist() plots three separate axes in a single figure.
# 1 & 2 plots three graphs into single graphs

# %% [markdown]
# ## Boxplot

# %% [raw]
# Two ways to Boxplot:
#     1.df["--"].plot(kind="bar")
#         > This plots a series.
#     2.df.boxplot()
#         > This plots an entire dataframe

# %%
bs = pd.read_csv("bestsellers.csv")
bs["User Rating"].plot(kind="box")
# Median line is at 4.7
# Majority lies b/w 4.5 and 4.8
# Out:
# <Axes: >

# %%
# we can verify this:
bs["User Rating"].median()
# Out:
# 4.7

# %%
bs["User Rating"].value_counts()
# Out:
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.6      1
# 3.3      1
# Name: User Rating, dtype: int64

# %% [markdown]
# ## Pandas line plot

# %% [raw]
# > Pandas default plot is line-plot
# > By default, the index become the x-axis
# > If we plot an entire dataframe, it plots index on x-axis and rest on y-axis
#   at once, this makes plot a mess.
# > Many functions are not available in Pandas, but pandas import it from
#   matplotlib

# %%
ufo["date_time"].dt.year.value_counts().sort_index().plot(kind="line",
                color="olive",linewidth=4)
# Here linewidth/linestyle are not a functions of pandas, but import it from Matplotlib.
# It acts as a 'middle-man' b/w matplotlib and user.
# Out:
# <Axes: >

# %% [raw]
# We can apply line plot directly to a dataframe but an tell which column
# to become x/y axis.

# %%
houses = pd.read_csv("kc_house_data.csv")
houses.plot.line(x="bedrooms",y="price")
# this creates a messy chart, trying scatterplot instead
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.plot.scatter(x="bedrooms",y="price")
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# ## Pandas Scatterplot

# %%
# Scatterplot requires x and y axis.
houses["bedrooms"].plot(kind="scatter")
# This creates an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Scatterplot requires x and y axis.
# ----> 2 houses["bedrooms"].plot(kind="scatter")
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     945         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     946     else:
# --> 947         raise ValueError(f"plot kind {kind} can only be used for data frames")
#     948 elif kind in self._series_kinds:
#     949     if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames

# %%
houses.plot.scatter(x="bedrooms",y="bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %% [markdown]
# ## Multiple plotting on the same axis

# %% [raw]
# Just like Matplotlib by default if we plot one after another, it gets plotted
# under single plot

# %%
ufo.head()
# Out:
#                                              summary        city state  \
# 0  My wife was driving southeast on a fairly popu...     Chester    VA
# 1  I think that I may caught a UFO on the NBC Nig...  Rocky Hill    CT
# 2  I woke up late in the afternoon 3:30-4pm. I we...         NaN   NaN
# 3  I was driving towards the intersection of fall...      Ottawa    ON
# 4  In Peoria Arizona, I saw a cigar shaped craft ...      Peoria    NY
#
#             date_time     shape     duration  \
# 0 2019-12-12 18:43:00     light    5 seconds
# 1 2019-03-22 18:30:00    circle  3-5 seconds
# 2                 NaT       NaN          NaN
# 3 2019-04-17 02:00:00  teardrop   10 seconds
# 4 2009-03-15 18:00:00     cigar    2 minutes
#
#                                                stats  \
# 0  Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1  Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2  Occurred : 4/1/2019 15:45  (Entered as : April...
# ...

# %%
ufo[ufo["state"]=="NY"]["date_time"].dt.year.value_counts().sort_index().plot()
ufo[ufo["state"]=="FL"]["date_time"].dt.year.value_counts().sort_index().plot()
plt.title("UFO Sightings by State")
plt.xlabel("Year")
# We can provide legends too
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ## Pandas automatic subplot

# %% [raw]
# In Matplotlib we set subplots separately, in Pandas it's easier.

# %%
pokemon[["Speed","Attack","Defense"]].head(10).plot(kind="hist",
        sharex=False,subplots=True,figsize=(10,10))
plt.tight_layout(pad=4)
# we can change padding

# %%
salary['OvertimePay'] = salary[['OvertimePay']].replace(["Not Provided"],np.nan)

# %%
salary['OtherPay'] = salary['OtherPay'].replace(["Not Provided"],np.nan)
salary['BasePay'] = salary['BasePay'].replace(["Not Provided"],np.nan)

# %%
df = salary[["BasePay","OvertimePay","OtherPay"]]
df = df.astype(float)

# %%
plt.style.use("ggplot")
df.plot(kind="hist",subplots=True,sharex=False,layout=(1,3),figsize=(10,3))
plt.tight_layout()

# %% [raw]
# Changing no:of bins

# %%
df.plot(kind="hist",subplots=True,sharex=False,layout=(1,3),figsize=(10,3),
        bins=30)
plt.tight_layout()

# %% [raw]
# For now, we don't have control over individual plots.
# For that, we've to put this into a variable.
# That variable is an 'array' of plots
#
# By this, we can manipulate individual plots like:
#     > bins
#     > xlabel
#     > title etc.

# %%
ax = pokemon[["Speed","Attack","Defense"]].head(10).plot(kind="hist",
            sharex=False,subplots=True,layout=(1,3),figsize=(10,4),bins=20)
plt.tight_layout()
ax[0][2].set_xlim(0,8,0)
ax[0][0].set_title("Left")
ax[0][1].set_title("Middle")
ax[0][2].set_title("Right")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_18004\4251301487.py:4: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   ax[0][2].set_xlim(0,8,0)
# Text(0.5, 1.0, 'Right')

# %% [raw]
# > To plot different types of plot i.e Bars and Line in a single figure we use
# manual sub-plotting

# %% [markdown]
# ## Manual Subplot with Pandas

# %% [raw]
# At first, we set total figure and axis,fig,axs=plt.subplots(1,2)
# here, 1 is figure and 2 is Axes.
#
# Note: Without using measured subplot, we cannot plot multiple charts in one figure.
# If we add two plots one after another the second one gets executed.
#
# eg: ufos......plot()
#     ufos......plot(kind="bar")
#     i.e only bar graph is printed

# %%
ufo["year"] = ufo["date_time"].dt.year

# %%
ufo["month"] = ufo["date_time"].dt.month

# %%
# To plot more than one type of graph in a single plot
fig, axs=plt.subplots(1,2)
ufo["year"].value_counts().sort_index().plot(ax=axs[0])
axs[0].set_title("Sightings By Year")
ufo["month"].value_counts().sort_index().plot(kind="bar",ax=axs[1])
axs[1].set_title("Sightings By Month")
# Out:
# Text(0.5, 1.0, 'Sightings By Month')

# %%
months = {1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"June",7:"July",8:"Aug",
         9:"Sept",10:"Oct",11:"Nov",12:"Dec"}
fig, axs = plt.subplots(2, 3,figsize=(14,8))
fig.suptitle("UFO sightings by month",fontsize=14)
fig.tight_layout(pad=2)
ufo[ufo["year"]==2014]["month"].value_counts().sort_index().rename(months).plot(kind="bar",ax=axs[0][0],title="2014")
ufo[ufo["year"]==2015]["month"].value_counts().sort_index().rename(months).plot(kind="bar",ax=axs[0][1],title="2015")
ufo[ufo["year"]==2016]["month"].value_counts().sort_index().rename(months).plot(kind="bar",ax=axs[0][2],title="2016")
ufo[ufo["year"]==2017]["month"].value_counts().sort_index().rename(months).plot(kind="bar",ax=axs[1][0],title="2017")
ufo[ufo["year"]==2018]["month"].value_counts().sort_index().rename(months).plot(kind="bar",ax=axs[1][1],title="2018")
ufo[ufo["year"]==2019]["month"].value_counts().sort_index().rename(months).plot(kind="bar",ax=axs[1][2],title="2019")
plt.tight_layout()

# %% [markdown]
# ## Exporting figure wtih savefig()

# %% [raw]
# This has to be updated
