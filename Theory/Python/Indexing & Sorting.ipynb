# %% [markdown]
# # Indexing & Sorting

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [raw]
# To set any column as index,
# df.set_index("col_name")

# %%
state = pd.read_csv("state_pops.csv")
state.set_index("state",inplace=True)
# It's temporary

# %%
state
# Out:
#        year   population
# state
# AL     2012    4817528.0
# AL     2010    4785570.0
# AL     2011    4801627.0
# AL     2009    4757938.0
# AL     2013    4833722.0
# ...     ...          ...
# USA    2013  316128839.0
# USA    2009  306771529.0
# USA    2010  309326295.0
# USA    2011  311582564.0
# USA    2012  313873685.0
#
# [1272 rows x 2 columns]

# %%
state.index
# Out:
# Index(['AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL',
#        ...
#        'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA'],
#       dtype='object', name='state', length=1272)

# %% [markdown]
# ## Sorting by multiple columns

# %%
# To sort a column
houses = pd.read_csv("kc_house_data.csv")
houses.sort_values("bedrooms")
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# ...           ...              ...        ...       ...        ...
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9773          2460      8049     2.0           0     0  ...      8
# ...

# %% [raw]
# To sort multiple columns.

# %%
houses.sort_values(["bedrooms","bathrooms"],ascending=False)
# First bedrooms gets sorted then bathrooms gets sorted.
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
> Sorting by number is simple.
but, when sorting is done by letter/alphabets

> Few points to remember:
    sort_values() sorts this way.
    ABCD...Zabcd....z
    
    A < a
    c > E
    Uppercase < Lowercase

# %% [raw]
# To sort columns regardless of cases (upper/lower)

# %%
titanic = pd.read_csv("titanic.csv")
titanic.sort_values("name",key=lambda col:col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %% [raw]
# This sorts names according alphabetically regardless of case (u/l)
#     i.e ABCD...Zabcd...z (wrong)
#         ABcCdD...Yz
#
#     Abby
#     alice
#     bianca
#     Browny
#     xian
#     Xeshan

# %%
titanic.sort_values("name",key=lambda col:col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %% [markdown]
# ## Sort Index

# %% [raw]
# > It doesn't make much sense to sort index.
#   By default, index is sorted numerically.
#
# > But, if we set a column on index, then it can be useful.

# %%
countries = pd.read_csv("world-happiness-report-2021.csv")
countries.set_index("Country name",inplace=True)

# %%
countries.head()
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark          Western Europe         7.620                           0.035
# Switzerland      Western Europe         7.571                           0.036
# Iceland          Western Europe         7.554                           0.059
# Netherlands      Western Europe         7.464                           0.027
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Switzerland          7.643         7.500                 11.117
# Iceland              7.670         7.438                 10.878
# Netherlands          7.518         7.410                 10.932
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
# Now, sort the index
countries.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
# To reverse order the index
countries.sort_index(ascending=False,inplace=True)
countries
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Zimbabwe                      Sub-Saharan Africa         3.145
# Zambia                        Sub-Saharan Africa         4.073
# Yemen               Middle East and North Africa         3.658
# Vietnam                           Southeast Asia         5.411
# Venezuela            Latin America and Caribbean         4.892
# ...                                          ...           ...
# Armenia       Commonwealth of Independent States         5.283
# Argentina            Latin America and Caribbean         5.929
# Algeria             Middle East and North Africa         4.887
# Albania               Central and Eastern Europe         5.117
# Afghanistan                           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259         3.030
# ...

# %% [markdown]
# ## Sorting and Plotting

# %%
titanic.pclass.value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %% [raw]
# value_counts sorts descending order by default

# %%
titanic.pclass.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## .loc[]

# %%
# To print dataframes based on rows.
countries.loc["India"]
# Out:
# Regional indicator                            South Asia
# Ladder score                                       3.819
# Standard error of ladder score                     0.026
# upperwhisker                                       3.869
# lowerwhisker                                       3.769
# Logged GDP per capita                              8.755
# Social support                                     0.603
# Healthy life expectancy                           60.633
# Freedom to make life choices                       0.893
# Generosity                                         0.089
# Perceptions of corruption                          0.774
# Ladder score in Dystopia                            2.43
# Explained by: Log GDP per capita                   0.741
# Explained by: Social support                       0.316
# Explained by: Healthy life expectancy              0.383
# Explained by: Freedom to make life choices         0.622
# ...

# %%
countries.loc[["China","United States","India"]]
# Out:
#                   Regional indicator  Ladder score  \
# Country name
# China                      East Asia         5.339
# United States  North America and ANZ         6.951
# India                     South Asia         3.819
#
#                Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# China                                   0.029         5.397         5.281
# United States                           0.049         7.047         6.856
# India                                   0.026         3.869         3.769
#
#                Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# China                          9.673           0.811                   69.593
# United States                 11.023           0.920                   68.200
# India                          8.755           0.603                   60.633
#
#                Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
countries.sort_index(inplace=True)
countries.loc["China":"India"]
# Out:
#                                            Regional indicator  Ladder score  \
# Country name
# China                                               East Asia         5.339
# Colombia                          Latin America and Caribbean         6.012
# Comoros                                    Sub-Saharan Africa         4.289
# Congo (Brazzaville)                        Sub-Saharan Africa         5.342
# Costa Rica                        Latin America and Caribbean         7.069
# Croatia                            Central and Eastern Europe         5.882
# Cyprus                                         Western Europe         6.223
# Czech Republic                     Central and Eastern Europe         6.965
# Denmark                                        Western Europe         7.620
# Dominican Republic                Latin America and Caribbean         5.545
# Ecuador                           Latin America and Caribbean         5.764
# ...

# %%
titanic.loc[12:50:6]
# Out:
#     pclass  survived                                              name  \
# 12       1         1                     Aubart, Mme. Leontine Pauline
# 18       1         1                             Bazzani, Miss. Albina
# 24       1         1                                 Bird, Miss. Ellen
# 30       1         0                      Blackwell, Mr. Stephen Weart
# 36       1         1                       Bowerman, Miss. Elsie Edith
# 42       1         1    Brown, Mrs. John Murray (Caroline Lane Lamson)
# 48       1         1  Candee, Mrs. Edward (Helen Churchill Hungerford)
#
#        sex age  sibsp  parch    ticket      fare cabin embarked boat body  \
# 12  female  24      0      0  PC 17477      69.3   B35        C    9    ?
# 18  female  32      0      0     11813   76.2917   D15        C    8    ?
# 24  female  29      0      0  PC 17483  221.7792   C97        S    8    ?
# 30    male  45      0      0    113784      35.5     T        S    ?    ?
# ...

# %% [markdown]
# ## .iloc[ ]

# %%
> While .loc[] prints "named index" or 'index'.

> .iloc prints based on position of the rows even if the dataframe is not indexed as numeric

# %%
countries.iloc[[5,10,15]]
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Australia                  North America and ANZ         7.183
# Belarus       Commonwealth of Independent States         5.534
# Botswana                      Sub-Saharan Africa         3.467
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Australia                              0.041         7.265         7.102
# Belarus                                0.047         5.625         5.442
# Botswana                               0.074         3.611         3.322
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Australia                    10.796           0.940                   73.900
# Belarus                       9.853           0.910                   66.253
# Botswana                      9.782           0.784                   59.269
#
#               Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# ## .loc[ ] and .iloc[ ] with series

# %%
# Print specific rows and specific columns
countries.loc[["Afghanistan","Pakistan","India"],["Ladder score","Social support"]]
# Out:
#               Ladder score  Social support
# Country name
# Afghanistan          2.523           0.463
# Pakistan             4.934           0.651
# India                3.819           0.603

# %% [raw]
# We can print ranged row along with specific columns.

# %%
titanic.loc[10:50:2,["name","age","embarked"]]
# Out:
#                                                  name age embarked
# 10                             Astor, Col. John Jacob  47        C
# 12                      Aubart, Mme. Leontine Pauline  24        C
# 14               Barkworth, Mr. Algernon Henry Wilson  80        S
# 16                           Baxter, Mr. Quigg Edmond  24        C
# 18                              Bazzani, Miss. Albina  32        C
# 20                      Beckwith, Mr. Richard Leonard  37        S
# 22                              Behr, Mr. Karl Howell  26        C
# 24                                  Bird, Miss. Ellen  29        S
# 26                            Bishop, Mr. Dickinson H  25        C
# 28                             Bissette, Miss. Amelia  35        S
# 30                       Blackwell, Mr. Stephen Weart  45        S
# 32                            Bonnell, Miss. Caroline  30        S
# 34                           Borebank, Mr. John James  42        S
# ...

# %%
# We can also write like this
countries.loc["Canada":"Denmark"]["Ladder score"]
# Out:
# Country name
# Canada                 7.103
# Chad                   4.355
# Chile                  6.172
# China                  5.339
# Colombia               6.012
# Comoros                4.289
# Congo (Brazzaville)    5.342
# Costa Rica             7.069
# Croatia                5.882
# Cyprus                 6.223
# Czech Republic         6.965
# Denmark                7.620
# Name: Ladder score, dtype: float64

# %%
houses["bedrooms"].value_counts().iloc[0]
# Prints the total no:of bedroom counts on zero index.
# Out:
# 9824

# %%
houses["bedrooms"].value_counts().loc[33]
# Prints the total no:of houses with 33 bedrooms
# Out:
# 1

# %%
titanic["age"].value_counts().loc["18"]
# Here 18 is string beause age was string type.
# Out:
# 39
